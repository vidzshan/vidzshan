# %% [markdown]
# <a href="https://colab.research.google.com/github/vidzshan/vidzshan/blob/main/HPI-GCN-OP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python >= 3.6

# PyTorch >= 1.1.0

# PyYAML, tqdm, tensorboardX

# We provide the dependency file of our experimental environment, you can install all dependencies by creating a new anaconda virtual environment and running pip install -r requirements.txt

# Run pip install -e torchlight

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# python --version 3.12.12
# pytorch 2.3.0 with latest torchaudio and torch vision version

# %%
# one-linear
# no broken tensorpack

# !pip install -q \
#     numpy opencv-python tqdm pyyaml yacs \
#     fvcore iopath portalocker \
#     scikit-learn scipy matplotlib \
#     tensorboard easydict loguru \
#     thop gdown

# %%
# !pip install gdown
import gdown

# File ID from your shared link
file_id = "1tEbuaEqMxAV7dNc4fqu1O4M7mC6CJ50w"
# Output path to the folder in your Drive
output_path = '/content/drive/My Drive/Colab Notebooks/Research/ntu/nturgb+d_skeletons120.zip'

gdown.download(f'https://drive.google.com/uc?id={file_id}', output_path, quiet=False)
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1tEbuaEqMxAV7dNc4fqu1O4M7mC6CJ50w
# From (redirected): https://drive.google.com/uc?id=1tEbuaEqMxAV7dNc4fqu1O4M7mC6CJ50w&confirm=t&uuid=064633ae-36c7-4c83-b163-b056340a48a9
# To: /content/drive/My Drive/Colab Notebooks/Research/ntu/nturgb+d_skeletons120.zip
# 100%|██████████| 4.78G/4.78G [01:43<00:00, 46.2MB/s]
# '/content/drive/My Drive/Colab Notebooks/Research/ntu/nturgb+d_skeletons120.zip'

# %%
import os
dest_folder = '/content/drive/My Drive/Colab Notebooks/Research/ntu/nturgb+d_skeletons'
os.makedirs(dest_folder, exist_ok=True)

# %%
import zipfile

zip_path = '/content/drive/My Drive/Colab Notebooks/Research/ntu/nturgbd_skeletons_s001_to_s017.zip'
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(dest_folder)

# %%
# !find "/content/drive/My Drive/Colab Notebooks/Research/ntu/nturgb+d_skeletons120" -name "*.skeleton" | wc -l
# Out:
# 57600

# %%
# !find "/content/drive/My Drive/Colab Notebooks/Research/ntu/nturgb+d_skeletons" -name "*.skeleton" | wc -l
# Out:
# 56880

# %%
# !git clone https://github.com/lizaowo/HPI-GCN.git
# Out:
# Cloning into 'HPI-GCN'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 142 (delta 33), reused 137 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (142/142), 539.04 KiB | 1.12 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# !cp -r "/content/drive/My Drive/Colab Notebooks/Research/ntu/nturgb+d_skeletons/." "/content/HPI-GCN/data/nturgbd_raw/nturgb+d_skeletons/"
# !cp -r "/content/drive/My Drive/Colab Notebooks/Research/ntu/nturgb+d_skeletons120/." "/content/HPI-GCN/data/nturgbd_raw/nturgb+d_skeletons120/"

# %%
# !ls /content/HPI-GCN/data/nturgbd_raw/nturgb+d_skeletons | head
# !ls /content/HPI-GCN/data/nturgbd_raw/nturgb+d_skeletons120 | head
# Out:
# nturgb+d_skeletons
# S018C001P008R001A061.skeleton
# S018C001P008R001A062.skeleton
# S018C001P008R001A063.skeleton
# S018C001P008R001A064.skeleton
# S018C001P008R001A065.skeleton
# S018C001P008R001A066.skeleton
# S018C001P008R001A067.skeleton
# S018C001P008R001A068.skeleton
# S018C001P008R001A069.skeleton
# S018C001P008R001A070.skeleton

# %%
# !rm -rf /content/HPI-GCN/data/nturgbd_raw/nturgb+d_skeletons/nturgb+d_skeletons

# %%
# !cp -r "/content/drive/My Drive/Colab Notebooks/Research/ntu/nturgb+d_skeletons/nturgb+d_skeletons/." "/content/HPI-GCN/data/nturgbd_raw/nturgb+d_skeletons/"

# %%
# !ls /content/HPI-GCN/data/nturgbd_raw/nturgb+d_skeletons | head
# Out:
# S001C001P001R001A001.skeleton
# S001C001P001R001A002.skeleton
# S001C001P001R001A003.skeleton
# S001C001P001R001A004.skeleton
# S001C001P001R001A005.skeleton
# S001C001P001R001A006.skeleton
# S001C001P001R001A007.skeleton
# S001C001P001R001A008.skeleton
# S001C001P001R001A009.skeleton
# S001C001P001R001A010.skeleton

# %%
# !cd content/HPI-GCN/data/ntu
# !ls
# Out:
# /bin/bash: line 1: cd: content/HPI-GCN/data/ntu: No such file or directory
# drive  HPI-GCN	sample_data

# %%
# !ls
# Out:
# drive  HPI-GCN	sample_data

# %%
# !python get_raw_skes_data.py
# Out:
# python3: can't open file '/content/get_raw_skes_data.py': [Errno 2] No such file or directory

# %%
# !ls
# Out:
# drive  HPI-GCN	sample_data

# %%
ls
# Out:
# drive/  HPI-GCN/  sample_data/

# %%
# !cd "/content/HPI-GCN/data/ntu"

# %%
# Out:
# config/  feeders/  main.py       model/     requirements.txt  torchlight/
# data/    graph/    Mensemble.py  README.md  src/              Transformer.py

# %%
#replace all dtype=np.int with dtype=int
import fileinput

filename = "/content/HPI-GCN/data/ntu/seq_transformation.py"
for line in fileinput.input(filename, inplace=True):
    print(line.replace("dtype=np.int", "dtype=int"), end="")

# %%
cd data
# Out:
# /content/HPI-GCN/data

# %%
cd ntu
# Out:
# /content/HPI-GCN/data/ntu

# %%
# Generating Data
# Generate NTU RGB+D 60 or NTU RGB+D 120 dataset:
#  cd ./data/ntu # or cd ./data/ntu120
#  # Get skeleton of each performer
#  python get_raw_skes_data.py
#  # Remove the bad skeleton
#  python get_raw_denoised_data.py
#  # Transform the skeleton to the center of the first frame
#  python seq_transformation.py

# %%
#Extract raw skeletons

# %%
# !python "get_raw_skes_data.py"
# Out:
# Streaming output truncated to the last 5000 lines.
# Reading data from S016C001P021R001A021.skeleton
# Reading data from S016C001P021R001A022.skeleton
# Reading data from S016C001P021R001A023.skeleton
# Reading data from S016C001P021R001A024.skeleton
# Reading data from S016C001P021R001A025.skeleton
# Reading data from S016C001P021R001A026.skeleton
# Reading data from S016C001P021R001A027.skeleton
# Reading data from S016C001P021R001A028.skeleton
# Reading data from S016C001P021R001A029.skeleton
# Reading data from S016C001P021R001A030.skeleton
# Reading data from S016C001P021R001A031.skeleton
# Reading data from S016C001P021R001A032.skeleton
# Reading data from S016C001P021R001A033.skeleton
# Reading data from S016C001P021R001A034.skeleton
# Reading data from S016C001P021R001A035.skeleton
# Reading data from S016C001P021R001A036.skeleton
# Reading data from S016C001P021R001A037.skeleton
# Reading data from S016C001P021R001A038.skeleton
# ...

# %%
#Remove Bad skeleton

# %%
# !python get_raw_denoised_data.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing S016C001P021R001A021
# Processing S016C001P021R001A022
# Processing S016C001P021R001A023
# Processing S016C001P021R001A024
# Processing S016C001P021R001A025
# Processing S016C001P021R001A026
# Processing S016C001P021R001A027
# Processing S016C001P021R001A028
# Processing S016C001P021R001A029
# Processing S016C001P021R001A030
# Processing S016C001P021R001A031
# Processing S016C001P021R001A032
# Processing S016C001P021R001A033
# Processing S016C001P021R001A034
# Processing S016C001P021R001A035
# Processing S016C001P021R001A036
# Processing S016C001P021R001A037
# Processing S016C001P021R001A038
# Processing S016C001P021R001A039
# Processing S016C001P021R001A040
# Processing S016C001P021R001A041
# Processing S016C001P021R001A042
# Processing S016C001P021R001A043
# Processing S016C001P021R001A044
# Processing S016C001P021R001A045
# Processing S016C001P021R001A046
# Processing S016C001P021R001A047
# ...

# %%
# !python seq_transformation.py
# Out:
# Traceback (most recent call last):
#   File "/content/HPI-GCN/data/ntu/seq_transformation.py", line 232, in <module>
#     skes_name = np.loadtxt(skes_name_file, dtype=np.string_)
#                                                  ^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/__init__.py", line 397, in __getattr__
#     raise AttributeError(
# AttributeError: `np.string_` was removed in the NumPy 2.0 release. Use `np.bytes_` instead.. Did you mean: 'strings'?

# %%
import fileinput

filename = "/content/HPI-GCN/data/ntu/seq_transformation.py"
for line in fileinput.input(filename, inplace=True):
    print(line.replace("dtype=np.string_", "dtype=np.bytes_"), end="")

# %%
# !python seq_transformation.py
# Out:
# Traceback (most recent call last):
#   File "/content/HPI-GCN/data/ntu/seq_transformation.py", line 243, in <module>
#     split_dataset(skes_joints, label, performer, camera, evaluation, save_path)
#   File "/content/HPI-GCN/data/ntu/seq_transformation.py", line 157, in split_dataset
#     train_indices, test_indices = get_indices(performer, camera, evaluation)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HPI-GCN/data/ntu/seq_transformation.py", line 205, in get_indices
#     test_indices = np.hstack((test_indices, temp)).astype(np.int)
#                                                           ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/__init__.py", line 394, in __getattr__
#     raise AttributeError(__former_attrs__[attr])
# AttributeError: module 'numpy' has no attribute 'int'.
# ...

# %%
import fileinput

filename = "/content/HPI-GCN/data/ntu/seq_transformation.py"
for line in fileinput.input(filename, inplace=True):
    print(line.replace("astype(np.int)", "astype(int)"), end="")

# %%
#Transform each skeleton to center on the first frame:

# %%
# !python seq_transformation.py

# %%
# Great! data generation pipeline has successfully completed:

# get_raw_skes_data.py saved the raw skeleton data.

# get_raw_denoised_data.py processed and saved the denoised skeleton joints, noting 138 files with missing data.

# seq_transformation.py completed successfully, transforming the skeleton sequences as needed.

# now I have fully processed NTU RGB+D skeleton data ready for use with the HPI-GCN model training or fine-tuning.

# %%
#TRAINING

# %%
import torchpack
print(torchpack.__version__)
print(dir(torchpack))
# Out:
# 0.3.1
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'version']

# %%
# !pip install --upgrade --force-reinstall torchpack
# Out:
# ...
#   Using cached torchpack-0.3.1-py3-none-any.whl.metadata (533 bytes)
# ...
#   Using cached loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached multimethod-2.0.2-py3-none-any.whl.metadata (8.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.4 MB/s eta 0:00:00
# ...
#   Using cached tensorpack-0.11-py2.py3-none-any.whl.metadata (5.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.1 MB/s eta 0:00:00
# ...
#   Using cached msgpack_numpy-0.4.8-py2.py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached torchpack-0.3.1-py3-none-any.whl (34 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 146.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 27.9 MB/s eta 0:00:00
# ...

# %%
# !python /content/HPI-GCN/main.py --config /content/HPI-GCN/config/nturgbd60-cross-subject/HPI_GCN_OP.yaml --model_args deploy=False --work-dir /content/HPI-GCN/work_dir/ntu60/xsub/HPI_GCN_OP_joint0 --device 0
# Out:
# Traceback (most recent call last):
#   File "/content/HPI-GCN/main.py", line 30, in <module>
#     from torchlight.torchlight import DictAction
#   File "/content/HPI-GCN/torchlight/torchlight/__init__.py", line 1, in <module>
#     from .util import IO
#   File "/content/HPI-GCN/torchlight/torchlight/util.py", line 16, in <module>
#     from torchpack.runner.hooks import PaviLogger
# ModuleNotFoundError: No module named 'torchpack.runner'
